# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Customer-Churn-Prediction.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder
from pandas.api.types import is_numeric_dtype
le = LabelEncoder()
for col in df.columns:
    if col == 'Churn':
        continue
    if is_numeric_dtype (df[col]):
        continue
    else:
        df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0        5375       0              0        1           0       1
# 1        3962       1              0        0           0      34
# 2        2564       1              0        0           0       2
# 3        5535       1              0        0           0      45
# 4        6511       0              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              1                0               0  ...
# 1             1              0                0               2  ...
# 2             1              0                0               2  ...
# 3             0              1                0               2  ...
# 4             1              0                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
x = df.drop(['customerID','Churn'],axis=1)
y = df['Churn']

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
rf.score(xtrain,ytrain)
# Out:
# 0.9985800496982605

# %%
rf.score(xtest,ytest)
# Out:
# 0.7955997161107168

# %%
#  After sampling

# %%
from imblearn.combine import SMOTETomek
from imblearn.over_sampling import SMOTE

sm = SMOTETomek(smote=SMOTE(k_neighbors=2), random_state=42)

# %%
newx,newy = sm.fit_resample(x,y)

# %%
x_train, x_test, y_train,y_test = train_test_split(newx,newy, test_size=0.2, random_state=42)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf.score(x_train,y_train)
# Out:
# 0.9982271748765353

# %%
rf.score(x_test,y_test)
# Out:
# 0.8556962025316456

# %%
y.value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
newy.value_counts()
# Out:
# Churn
# No     4936
# Yes    4936
# Name: count, dtype: int64

# %%
# Oversampling

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler()
new_x, new_y = ros.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
new_y.value_counts()
# Out:
# Churn
# No     5174
# Yes    5174
# Name: count, dtype: int64

# %%
xtrain1, xtest1, ytrain1,ytest1  = train_test_split(new_x, new_y, test_size = 0.2, random_state=42)
rf.fit(xtrain1,ytrain1)
# Out:
# RandomForestClassifier()

# %%
rf.score(xtrain1,ytrain1)
# Out:
# 0.9980671659821213

# %%
rf.score(xtest1,ytest1)
# Out:
# 0.8951690821256039

# %%
# Undersampling

# %%
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler()
newx1, newy1 = rus.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
newy1.value_counts()
# Out:
# Churn
# No     1869
# Yes    1869
# Name: count, dtype: int64

# %%
xtrain2, xtest2,ytrain2,ytest2 = train_test_split(newx1,newy1, test_size=0.2, random_state = 42)

# %%
rf.fit(xtrain2,ytrain2)
# Out:
# RandomForestClassifier()

# %%
rf.score(xtrain2,ytrain2)
# Out:
# 0.9983277591973244

# %%
rf.score(xtest2,ytest2)
# Out:
# 0.7446524064171123

# %%
# k fold

# %%
from sklearn.model_selection import KFold, cross_val_score
kfold = KFold(n_splits=5, shuffle=True)

# %%
model = cross_val_score(rf,x,y,cv=kfold)

# %%
model.mean()
# Out:
# 0.7918497765984902

# %%
model
# Out:
# array([0.79347055, 0.78495387, 0.79914833, 0.78338068, 0.79829545])

# %%
# SMOTE

# %%
from imblearn.combine import SMOTETomek
from imblearn.over_sampling import SMOTE
sm = SMOTETomek(smote=SMOTE(k_neighbors=2),random_state = 100)
newx2,newy2 = sm.fit_resample(x,y)

# %%
model2 = cross_val_score(rf,newx2,newy2,cv=kfold)

# %%
model2
# Out:
# array([0.85145482, 0.86830015, 0.86874362, 0.86976507, 0.86159346])

# %%
model2.mean()
# Out:
# 0.8639714244150124

# %%
from sklearn.model_selection import KFold,cross_val_score
kfold = KFold(n_splits=2,shuffle=True)

# %%
rf = RandomForestClassifier()
cross_val_score(rf,x,y,cv=kfold)
# Out:
# array([0.78733674, 0.79664868])

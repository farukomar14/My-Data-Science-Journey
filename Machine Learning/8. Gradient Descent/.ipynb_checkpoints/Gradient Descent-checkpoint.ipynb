# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
df = pd.read_csv('Height-Weight Data.csv')
df
# Out:
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 3496  69.296830  185.649086
# 3497  70.542201  210.198845
# 3498  73.912549  202.429960
# 3499  67.396021  144.277671
# 3500  72.738970  187.222909
#
# [3501 rows x 2 columns]

# %%
df.shape
# Out:
# (3501, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3501 entries, 0 to 3500
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  3501 non-null   float64
#  1   Weight  3501 non-null   float64
# dtypes: float64(2)
# memory usage: 54.8 KB

# %%
df.isna().sum()
# Out:
# Height    0
# Weight    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plt.scatter(df.Height, df.Weight, marker = '*', color = 'b')
plt.xlabel('Values of Height')
plt.ylabel('Values of Weight')
plt.title("Distribution of Data")
plt.show()

# %%
plt.scatter(df.Height, df.Weight, marker = '*', color = 'b')
plt.plot(df.Height, df.Weight, color = 'r')

plt.xlabel('Values of Height')
plt.ylabel('Values of Weight')
plt.title("Distribution of Data")
plt.show()

# %%
# Data Split
x = df.drop('Weight', axis = 1)
y = df[['Weight']]

# %%
x.head()
# Out:
#       Height
# 0  73.847017
# 1  68.781904
# 2  74.110105
# 3  71.730978
# 4  69.881796

# %%
y.head()
# Out:
#        Weight
# 0  241.893563
# 1  162.310473
# 2  212.740856
# 3  220.042470
# 4  206.349801

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
print(f'Shape of XTRAIN data: {xtrain.shape}')
print(f'Shape of YTRAIN data: {ytrain.shape}')
print(f'Shape of XTEST data: {xtest.shape}')
print(f'Shape of YTEST data: {ytest.shape}')
# Out:
# Shape of XTRAIN data: (2800, 1)
# Shape of YTRAIN data: (2800, 1)
# Shape of XTEST data: (701, 1)
# Shape of YTEST data: (701, 1)

# %%
# Apply Linear Model
lr = LinearRegression()
lr.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
lr.score(xtrain, ytrain)
# Out:
# 0.728885573697805

# %%
pred = lr.predict(xtest)
pred
# Out:
# array([[194.52602871],
#        [176.32221443],
#        [187.47569079],
#        [235.28479353],
#        [208.55066489],
#        [188.65262141],
#        [175.7815701 ],
#        [185.78481771],
#        [173.36073152],
#        [202.75084787],
#        [174.60458851],
#        [218.38085184],
#        [201.04996482],
#        [197.93188467],
#        [182.77830568],
#        [176.85410589],
#        [202.8203235 ],
#        [200.51903044],
#        [174.19532494],
#        [185.6276918 ],
#        [178.87851946],
#        [165.69822081],
#        [171.96478941],
#        [177.26568654],
#        [188.00332531],
#        [175.87446611],
#        [190.31072367],
#        [182.86506281],
#        [179.50428904],
#        [163.93926807],
#        [170.69319143],
#        [197.17335484],
#        [171.52507998],
#        [188.04079205],
#        [200.6829025 ],
#        [189.44894806],
#        [167.1960159 ],
#        [202.30641997],
#        [172.72262624],
#        [169.58152465],
#        [199.39304483],
#        [167.75318095],
#        [181.3692217 ],
#        [211.19037957],
#        [200.97256616],
#        [187.16182478],
#        [164.56032669],
#        [183.1386456 ],
#        [186.72444835],
#        [201.70146882],
#        [188.35356636],
#        [188.39721061],
#        [181.2193706 ],
#        [202.16269708],
#        [183.77879691],
#        [193.68412667],
#        [178.75763855],
#        [203.13390468],
#        [190.97278738],
#        [179.69684908],
#        [160.98519091],
#        [205.25915478],
#        [169.83737886],
#        [189.4363019 ],
#        [180.69745305],
#        [221.57207278],
#        [228.52518754],
#        [179.55967896],
#        [184.1852787 ],
#        [184.80748417],
#        [214.07205307],
#        [206.41144679],
#        [188.12225118],
#        [176.96878467],
#        [180.87216194],
#        [203.81979123],
#        [215.24024888],
#        [177.63752177],
#        [206.67343111],
#        [195.18186608],
#        [175.35920891],
#        [185.12722051],
#        [177.23221396],
#        [205.6903512 ],
#        [219.68934418],
#        [174.10807442],
#        [180.65559905],
#        [188.67519824],
#        [194.76833294],
#        [181.50332957],
#        [216.77549377],
#        [188.88683803],
#        [204.39520983],
#        [207.85817066],
#        [176.21316039],
#        [183.44097444],
#        [194.91028455],
#        [174.13503541],
#        [201.00112339],
#        [168.33785935],
#        [182.07151443],
#        [176.94682887],
#        [167.33029572],
#        [170.83517703],
#        [159.26944055],
#        [172.66818916],
#        [188.07351934],
#        [185.0369552 ],
#        [204.8118599 ],
#        [156.74376955],
#        [183.59527171],
#        [184.17903667],
#        [171.78146818],
#        [172.2710609 ],
#        [191.12960885],
#        [198.95098821],
#        [198.2151969 ],
#        [137.01974564],
#        [180.01164336],
#        [179.99271106],
#        [201.02248343],
#        [197.33781424],
#        [209.05596949],
#        [190.8145031 ],
#        [173.28437549],
#        [205.11241906],
#        [211.10908816],
#        [178.90818104],
#        [199.72418663],
#        [203.37670951],
#        [197.88122908],
#        [188.33217024],
#        [156.66268856],
#        [177.06396067],
#        [201.05058276],
#        [200.50175895],
#        [203.61071876],
#        [164.5216886 ],
#        [219.00584882],
#        [178.18440544],
#        [213.13704413],
#        [200.56626932],
#        [163.9347147 ],
#        [209.77142722],
#        [202.22770262],
#        [188.38133656],
#        [211.07818654],
#        [171.56517396],
#        [178.51396197],
#        [179.48480373],
#        [175.72454287],
#        [181.06085129],
#        [172.18657231],
#        [181.17180248],
#        [184.00908036],
#        [151.91829388],
#        [204.13213476],
#        [207.13484819],
#        [184.3504621 ],
#        [166.75827571],
#        [211.20417097],
#        [185.79913487],
#        [170.3868534 ],
#        [193.35224853],
#        [195.86450351],
#        [167.06011427],
#        [150.38807153],
#        [185.21110648],
#        [139.37289629],
#        [179.35695857],
#        [183.53818306],
#        [184.2225829 ],
#        [205.62334726],
#        [186.41495541],
#        [163.93703655],
#        [159.70982373],
#        [193.91801901],
#        [143.48703623],
#        [161.75300201],
#        [178.35300997],
#        [171.02743179],
#        [170.98535748],
#        [190.62291266],
#        [187.70159247],
#        [170.30744489],
#        [152.49843971],
#        [183.66569134],
#        [193.2998418 ],
#        [172.7756171 ],
#        [167.18355815],
#        [187.23547075],
#        [169.40361006],
#        [175.76544666],
#        [180.44409067],
#        [188.89490256],
#        [203.17734091],
#        [186.15663523],
#        [173.33165408],
#        [173.061207  ],
#        [185.39574521],
#        [176.89422992],
#        [205.86625529],
#        [207.73020655],
#        [180.58146274],
#        [215.18032061],
#        [218.86263403],
#        [196.1493985 ],
#        [199.01573743],
#        [170.82653499],
#        [171.64545898],
#        [184.48291244],
#        [190.03446768],
#        [206.02110878],
#        [179.40583566],
#        [203.57997574],
#        [201.31718866],
#        [177.49175761],
#        [218.00045393],
#        [194.26612369],
#        [209.720725  ],
#        [192.60154812],
#        [166.97878977],
#        [213.85764563],
#        [205.04015885],
#        [214.18337297],
#        [196.0187461 ],
#        [196.53882803],
#        [166.97984146],
#        [195.86472829],
#        [184.9611161 ],
#        [195.46134155],
#        [183.07223187],
#        [225.17382655],
#        [181.32748104],
#        [233.17140274],
#        [186.128323  ],
#        [187.51446006],
#        [229.05936942],
#        [173.83749474],
#        [178.14393619],
#        [189.17024292],
#        [190.02090338],
#        [161.17974839],
#        [183.43383473],
#        [172.76861697],
#        [207.19057164],
#        [187.4614246 ],
#        [166.50458546],
#        [192.52983836],
#        [223.33674918],
#        [160.08891893],
#        [216.59259313],
#        [147.38594956],
#        [206.77218523],
#        [175.4202873 ],
#        [197.81862761],
#        [202.90225359],
#        [204.03873642],
#        [163.38656422],
#        [175.22017264],
#        [180.2678961 ],
#        [188.72488615],
#        [154.69353313],
#        [169.37265847],
#        [151.94836674],
#        [167.71607213],
#        [185.38755118],
#        [180.87433324],
#        [170.09673189],
#        [217.06247266],
#        [185.99193364],
#        [182.4286118 ],
#        [179.78343813],
#        [186.72321039],
#        [161.01200732],
#        [169.12879194],
#        [168.66272382],
#        [221.45635661],
#        [154.01129159],
#        [193.71523393],
#        [200.06373072],
#        [179.09786258],
#        [182.32763039],
#        [170.37606582],
#        [185.20388831],
#        [187.62810795],
#        [177.66612229],
#        [216.36664297],
#        [193.8634687 ],
#        [183.77771421],
#        [183.87865012],
#        [210.92781821],
#        [188.12764131],
#        [177.7454593 ],
#        [175.15500855],
#        [154.40970146],
#        [180.5061897 ],
#        [170.10636886],
#        [209.76775967],
#        [182.68176329],
#        [166.82288106],
#        [208.13769204],
#        [199.83947893],
#        [191.0993529 ],
#        [198.41190112],
#        [183.22514295],
#        [209.68724193],
#        [182.1976825 ],
#        [203.0322995 ],
#        [205.24493761],
#        [178.8810838 ],
#        [197.82844154],
#        [194.19575318],
#        [180.60672357],
#        [184.20316032],
#        [156.4775602 ],
#        [163.2020981 ],
#        [194.37950757],
#        [176.98723581],
#        [199.79935574],
#        [195.42259845],
#        [167.28262774],
#        [169.0621743 ],
#        [143.54077244],
#        [176.87000318],
#        [182.176455  ],
#        [176.61532796],
#        [198.3644219 ],
#        [172.06280545],
#        [215.86470835],
#        [167.40282632],
#        [175.58612979],
#        [186.01340709],
#        [167.87114641],
#        [171.56227996],
#        [182.93062637],
#        [166.32151888],
#        [196.95452704],
#        [197.62231977],
#        [173.52687802],
#        [199.16890525],
#        [203.14164331],
#        [172.87300876],
#        [198.8949698 ],
#        [180.94409654],
#        [192.11765867],
#        [175.42719561],
#        [160.2315667 ],
#        [198.3569034 ],
#        [186.6939561 ],
#        [243.43773926],
#        [185.27076811],
#        [214.10399971],
#        [188.66871391],
#        [161.63703423],
#        [179.85606842],
#        [154.81652364],
#        [182.13701652],
#        [184.52516884],
#        [179.1850908 ],
#        [191.96610461],
#        [159.92123104],
#        [189.81643329],
#        [205.16496363],
#        [213.8291702 ],
#        [203.95397357],
#        [188.08062447],
#        [213.67651877],
#        [204.40234728],
#        [198.75973422],
#        [199.73224137],
#        [196.82859031],
#        [219.10187994],
#        [197.76961309],
#        [188.59029134],
#        [217.32063322],
#        [183.31570793],
#        [201.04400041],
#        [189.78548654],
#        [199.24475425],
#        [189.65735948],
#        [203.27436714],
#        [190.12107665],
#        [198.08608159],
#        [227.68063119],
#        [149.12021098],
#        [180.46217245],
#        [174.68416837],
#        [182.73307157],
#        [186.04741639],
#        [171.50363479],
#        [144.51740952],
#        [202.13958351],
#        [189.91864872],
#        [180.49909131],
#        [158.77487036],
#        [187.60750703],
#        [199.17566707],
#        [143.34482478],
#        [185.21710542],
#        [186.24795564],
#        [206.0551191 ],
#        [167.98460536],
#        [200.18173296],
#        [217.75777575],
#        [170.9318225 ],
#        [190.08013924],
#        [191.26557005],
#        [182.58169138],
#        [198.30194689],
#        [187.72942683],
#        [181.07347294],
#        [196.85456961],
#        [213.70344829],
#        [182.12264522],
#        [187.00953008],
#        [174.2782784 ],
#        [195.02683532],
#        [175.75281218],
#        [195.46764707],
#        [173.84845666],
#        [207.17567471],
#        [164.01436522],
#        [163.85689951],
#        [177.44482287],
#        [185.580735  ],
#        [183.8215898 ],
#        [154.62320758],
#        [186.36077787],
#        [203.19669773],
#        [190.98664103],
#        [180.08876692],
#        [195.31034395],
#        [189.92618087],
#        [201.10141495],
#        [193.31593055],
#        [171.21408871],
#        [160.31718115],
#        [178.07170829],
#        [171.74433581],
#        [203.30265923],
#        [190.60860307],
#        [178.33443857],
#        [189.07915486],
#        [200.6551692 ],
#        [207.75377552],
#        [168.1638756 ],
#        [220.31163807],
#        [204.27917378],
#        [177.0386386 ],
#        [192.83668313],
#        [196.26101008],
#        [200.30458651],
#        [198.57329767],
#        [180.77883384],
#        [150.92764091],
#        [176.43645385],
#        [189.66416965],
#        [214.54581706],
#        [186.9785017 ],
#        [189.54446236],
#        [199.52525214],
#        [197.9645478 ],
#        [177.33533322],
#        [193.21451199],
#        [171.81199047],
#        [190.00205938],
#        [167.36025124],
#        [213.63846176],
#        [202.41315491],
#        [203.17192932],
#        [154.26038107],
#        [169.58527012],
#        [206.08968183],
#        [205.05040899],
#        [185.28580809],
#        [194.70656613],
#        [172.05897942],
#        [182.04316832],
#        [177.1415013 ],
#        [182.4932847 ],
#        [186.61815278],
#        [191.95662349],
#        [226.56677939],
#        [204.3331331 ],
#        [163.92800416],
#        [182.37284798],
#        [192.86969148],
#        [195.43729834],
#        [221.68774447],
#        [174.03389642],
#        [170.24382965],
#        [177.39301297],
#        [199.05769935],
#        [192.48177328],
#        [184.40278321],
#        [198.88395899],
#        [154.85587704],
#        [172.07995346],
#        [204.02728923],
#        [197.28027645],
#        [176.46373193],
#        [191.7312995 ],
#        [182.14638226],
#        [207.05319541],
#        [215.52692344],
#        [176.13798049],
#        [184.29142258],
#        [192.55011481],
#        [174.51754017],
#        [176.4063903 ],
#        [148.58754538],
#        [185.2495328 ],
#        [178.09021006],
#        [198.05452525],
#        [175.84842576],
#        [213.23612374],
#        [162.12477523],
#        [176.65282248],
#        [172.65269206],
#        [190.50553461],
#        [197.49027958],
#        [189.45702534],
#        [208.6195478 ],
#        [199.82748809],
#        [178.7093469 ],
#        [172.52466094],
#        [196.06345636],
#        [175.63265581],
#        [208.71548353],
#        [172.50505042],
#        [188.38955808],
#        [195.14444328],
#        [215.00541766],
#        [183.62319443],
#        [161.7118611 ],
#        [187.97084648],
#        [192.70965904],
#        [195.77103059],
#        [200.45660617],
#        [164.77504525],
#        [160.44145076],
#        [178.57791576],
#        [202.57898868],
#        [193.64480809],
#        [210.35420685],
#        [206.55461155],
#        [190.02462661],
#        [172.68213964],
#        [196.72416548],
#        [181.44776412],
#        [167.87566555],
#        [163.89436852],
#        [193.72988511],
#        [195.89315077],
#        [168.75215757],
#        [193.87132753],
#        [214.10842274],
#        [226.54111603],
#        [188.39996365],
#        [179.506483  ],
#        [190.6610966 ],
#        [198.15408703],
#        [186.68834382],
#        [181.83422345],
#        [162.01832005],
#        [202.95641229],
#        [178.85911584],
#        [162.0591471 ],
#        [192.43651515],
#        [191.24178382],
#        [176.13788003],
#        [199.63993009],
#        [205.54920069],
#        [180.58383849],
#        [184.05392042],
#        [200.04346458],
#        [189.10845363],
#        [185.21893979],
#        [165.62968026],
#        [181.35475607],
#        [201.7781814 ],
#        [177.83082674],
#        [175.69962206],
#        [192.73709768],
#        [195.50902063],
#        [200.52002401],
#        [177.97648745],
#        [233.38804511],
#        [181.44190601],
#        [182.74304774],
#        [188.56432319],
#        [202.18050429],
#        [192.24126723],
#        [201.97876077],
#        [216.53980445],
#        [197.91940689],
#        [163.24168195],
#        [163.04904833],
#        [204.96469228],
#        [170.99663815],
#        [202.73305897],
#        [205.07168776],
#        [210.65614778],
#        [177.12200001],
#        [184.00987598],
#        [181.52385453],
#        [160.25789145],
#        [188.92088782],
#        [188.59409644],
#        [167.97933311],
#        [171.95896344],
#        [188.59261354],
#        [198.35880479],
#        [209.07778762],
#        [162.69163264],
#        [179.14294232],
#        [134.57096001],
#        [168.38058337],
#        [182.3404993 ],
#        [216.64063048],
#        [207.74196736],
#        [220.65421097],
#        [212.27655215],
#        [149.59533593],
#        [199.75443233],
#        [201.69331695],
#        [208.26543667],
#        [201.47468043],
#        [190.67672673],
#        [195.83329567],
#        [213.96277365],
#        [165.49605266],
#        [172.80818125],
#        [195.94868582],
#        [172.99723043],
#        [199.56931346],
#        [182.23227975],
#        [169.01137657],
#        [167.77686004],
#        [195.17660062],
#        [182.45987688],
#        [203.91049018],
#        [176.05612105],
#        [178.27671881],
#        [154.11107403],
#        [180.69974849],
#        [205.47758435],
#        [199.30978072],
#        [178.59335289],
#        [177.64131137],
#        [190.01802465],
#        [163.24627914],
#        [197.32992828],
#        [190.28226172],
#        [193.39624062],
#        [172.21049198],
#        [167.5357549 ],
#        [182.13148318],
#        [183.4043553 ],
#        [185.19044779],
#        [210.27329465],
#        [190.34144916],
#        [202.70865974],
#        [206.72006589],
#        [215.84245986],
#        [194.55858327],
#        [153.19758034],
#        [222.46067882],
#        [203.16814181],
#        [187.64435584],
#        [174.65009169],
#        [189.37501088],
#        [169.62793315],
#        [185.26404368],
#        [168.57982998],
#        [167.60705768],
#        [212.61352606],
#        [189.75730136],
#        [185.23319191],
#        [167.30588249],
#        [185.88464857],
#        [179.71069915],
#        [194.32689133],
#        [169.82484581],
#        [159.40679705],
#        [203.09385912],
#        [206.27175711],
#        [190.45466861],
#        [202.67125889],
#        [169.30278802],
#        [169.16890565],
#        [198.2350895 ],
#        [179.59838276],
#        [195.37461965],
#        [183.18814497],
#        [180.03770673],
#        [179.0588984 ],
#        [206.62966607],
#        [163.36857712],
#        [179.12435375]])

# %%
# Model Evaluation

# %%
# Visualization: Entire Dataset
plt.scatter(x,y,marker = '*',color = 'b')
plt.plot(x,lr.predict(x),color = 'r')
plt.show()

# %%
# Visualization: Test Data Only
plt.scatter(xtest,ytest,marker = '*',color = 'b')
plt.plot(xtest,lr.predict(xtest),color = 'r')
plt.show()

# %%
mse = mean_squared_error(ytest,pred)
mse
# Out:
# 97.21750513299327

# %%
rmse = np.sqrt(mse)
mae = mean_absolute_error(ytest,pred)
r2 = r2_score(ytest,pred)

print("RMSE:", rmse)
print("MAE:", mae)
print("R2 Score:", r2)
# Out:
# RMSE: 9.8598937688493
# MAE: 8.040126312816263
# R2 Score: 0.7461790585161445

# %%
# Linear Regression with Gradient Descent

# %%
import numpy as np

x = np.array(x).reshape(-1)
y = np.array(y).reshape(-1)

m = 0
c = 0
l = 0.0001
n = len(x)
iterations = 1000

for i in range(iterations):
    pred = (m * x) + c
    
    der_m = (-2/n) * np.sum(x * (y - pred))
    der_c = (-2/n) * np.sum(y - pred)
    
    m = m - l * der_m
    c = c - l * der_c
    
    if i % 100 == 0:
        cost = (1/n) * np.sum((y - pred)**2)
        print(f"Iter {i}: m={m}, c={c}, cost={cost}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 15
#      12 for i in range(iterations):
#      13     pred = (m * x) + c
# ---> 15     der_m = (-2/n) * np.sum(x * (y - pred))
#      16     der_c = (-2/n) * np.sum(y - pred)
#      18     m = m - l * der_m
#
# ValueError: operands could not be broadcast together with shapes (200,) (3501,)
